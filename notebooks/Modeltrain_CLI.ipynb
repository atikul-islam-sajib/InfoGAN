# %%
# Clone the GitHub
# !git clone https://github.com/atikul-islam-sajib/InfoGAN.git
# Out:
# Cloning into 'InfoGAN'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 251 (delta 20), reused 55 (delta 9), pack-reused 182
# Receiving objects: 100% (251/251), 314.15 MiB | 27.55 MiB/s, done.
# Resolving deltas: 100% (100/100), done.
# Updating files: 100% (73/73), done.

# %%
# Change the directory
# %cd InfoGAN
# Out:
# /content/InfoGAN

# %%
# Connect the gpu
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

device
# Out:
# device(type='cuda')

# %%
# Train the model
# !python /content/InfoGAN/src/cli.py --batch_size 64 --image_size 32 --in_channels 1 --latent_space 100 --epochs 5 --lr 0.0001 --device cuda --data
# Out:
# Exception caught in the section # [Errno 21] Is a directory: './data/raw/MNIST'
# Epochs - 1/5 [=======] g_loss: 4.5026140213012695 - d_loss: 0.5481956601142883 - q_loss: 2.311311960220337
# Epochs - 2/5 [=======] g_loss: 4.370450973510742 - d_loss: 0.5048742294311523 - q_loss: 2.31384539604187
# Epochs - 3/5 [=======] g_loss: 3.593200206756592 - d_loss: 0.5329402312636375 - q_loss: 2.3084070682525635
# Epochs - 4/5 [=======] g_loss: 4.839197158813477 - d_loss: 0.3297578692436218 - q_loss: 2.30228853225708
# Epochs - 5/5 [=======] g_loss: 4.840959072113037 - d_loss: 0.3238295838236809 - q_loss: 2.301604986190796

# %%
# Test the model
# !python /content/InfoGAN/src/cli.py --num_samples 20 --latent_space 100 --device cuda --test
# Out:
# Figure(640x480)

# %%
# Display the Image
from IPython.display import Image
Image("/content/InfoGAN/outputs/output_image/generated_images.png")
